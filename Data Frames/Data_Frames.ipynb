# %%
import pandas as pd

# %%
import numpy as np

# %%
#Creating data frames
# Create a dataframe from a dictionary
df= pd.DataFrame({
'a': [1, 2, 3],
'b': np.array([4, 4, 6]),
'c': ['x', 'y', 'z'],
'd': [np.nan, np.nan, np.nan]
})
df
# Out:
#    a  b  c   d
# 0  1  4  x NaN
# 1  2  4  y NaN
# 2  3  6  z NaN

# %%
# Create a dataframe from a list of dictionaries
df= pd.DataFrame([
{'a': 1, 'b': 4, 'c': 'x', 'd':np.nan},
{'a': 1, 'b': 4, 'c': 'y', 'd':np.nan},
{'a': 3, 'b': 6, 'c': 'z', 'd':np.nan}
])
df
# Out:
#    a  b  c   d
# 0  1  4  x NaN
# 1  1  4  y NaN
# 2  3  6  z NaN

# %%
# Create a dataframe from a list of dictionaries
df= pd.DataFrame([
{'a': 1, 'b': 4, 'c': 'x', 'd':np.nan},
{'a': 1, 'b': 4, 'c': 'y', 'd':np.nan},
{'a': 3, 'b': 6, 'c': 'z', 'd':np.nan}
])
df
# Out:
#    a  b  c   d
# 0  1  4  x NaN
# 1  1  4  y NaN
# 2  3  6  z NaN

# %%
#Data frame operations
# Create a DataFrame with 5 elements
data = {'Column1': [1, 2, 3, 4, 5]}
df = pd.DataFrame(data)
print(df)
# Out:
#    Column1
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
# Concatenate DataFrames vertically
x=pd.concat([df, df],axis=0 )
print(x)
y=pd.concat([df, df],axis=1 )
print(y)
# Out:
#    Column1
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#    Column1  Column1
# 0        1        1
# 1        2        2
# 2        3        3
# 3        4        4
# 4        5        5

# %%
# Concatenate DataFrames horizontally
pd.concat([df,df],axis="columns")
# Out:
#    Column1  Column1
# 0        1        1
# 1        2        2
# 2        3        3
# 3        4        4
# 4        5        5

# %%
# Get rows matching a condition
result = x.query("Column1 > 3")
print(result)
# Out:
#    Column1
# 3        4
# 4        5
# 3        4
# 4        5

# %%
y.columns
y.columns.values[1] = 'Column2'
print(y)
# Out:
#    Column1  Column2
# 0        1        1
# 1        2        2
# 2        3        3
# 3        4        4
# 4        5        5

# %%
# Assuming y is your DataFrame
y.drop(columns=['Column1'], inplace=True)
print(y)
# Out:
#    Column2
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
# Rename columns
y.rename(columns={"Column2": "ColumnX"}, inplace=True)
print(y)
# Out:
#    ColumnX
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
# Add a new column
# Assuming y is your DataFrame
y = y.assign(ColumnY=y['ColumnX'] * 5)
print(y)
# Out:
#    ColumnX  ColumnY
# 0        1        5
# 1        2       10
# 2        3       15
# 3        4       20
# 4        5       25
